# %% [markdown]
# ## LET'S DO IT

# %%
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from google import genai

# %%
load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

if api_key and api_key.startswith('AQ'):
    print("all good")
else:
    print("There might be a problem with your API key?")

MODEL = 'gemini-2.5-flash'
client = genai.Client(api_key=api_key)
# Out:
# all good

# %%
link_system_prompt = """
You are provided with a list of links found on a webpage.
You are able to decide which of the links would be most relevant to include in a brochure about the company,
such as links to an About page, or a Company page, or Careers/Jobs pages.
You should respond in JSON as in this example:

{
    "links": [ 
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(url):
    user_prompt = f"""
Here is the list of links on the website {url} -
Please decide which of these are relevant web links for a brochure about the company, 
respond with the full https URL in JSON format.
Do not include Terms of Service, Privacy, email links.

Links (some might be relative links):

"""
    links = fetch_website_links(url)
    user_prompt += "\n".join(links)
    return user_prompt

# %%
print(get_links_user_prompt("https://edwarddonner.com"))

# %%
# def select_relevant_links(url):
#     response = gemini.chat.completions.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": link_system_prompt},
#             {"role": "user", "content": get_links_user_prompt(url)}
#         ],
#         response_format={"type": "json_object"}
#     )
#     result = response.choices[0].message.content
#     links = json.loads(result)
#     return links

# %%
MODEL = 'gemini-3.5-flash-lite'
def select_relevant_links(url):
    response = client.models.generate_content(
        model=MODEL,
        contents=get_links_user_prompt(url),
        config={
            "system_instruction": link_system_prompt,
            "response_mime_type": "application/json"
        }
    )
    result = response.text
    links = json.loads(result)
    return links

# %%
select_relevant_links("https://edwarddonner.com")
# Out:
# {'links': [{'type': 'about page',
#    'url': 'https://edwarddonner.com/about-me-and-about-nebula/'},
#   {'type': 'curriculum page', 'url': 'https://edwarddonner.com/curriculum/'},
#   {'type': 'posts page', 'url': 'https://edwarddonner.com/posts/'}]}

# %%
def fetch_page_and_all_relevant_links(url):
    contents = fetch_website_contents(url)
    relevant_links = select_relevant_links(url)
    result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
    for link in relevant_links['links']:
        result += f"\n\n### Link: {link['type']}\n"
        result += fetch_website_contents(link["url"])
    return result

# %%
ans =fetch_page_and_all_relevant_links("https://en.wikipedia.org/wiki/Government_of_India")
display(Markdown(ans))
# Out:
# ## Landing Page:
#
# Government of India - Wikipedia
#
# Jump to content
# Main menu
# Main menu
# move to sidebar
# hide
# Navigation
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Contribute
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Special pages
# Search
# Search
# Appearance
# Donate
# Create account
# Log in
# Personal tools
# Donate
# Create account
# Log in
# Contents
# move to sidebar
# hide
# (Top)
# 1
# History
# Toggle History subsection
# 1.1
# British colonial rule: (1857–1947)
# 1.2
# Dominion: (1947–1950)
# 1.3
# Republic: (1950–present)
# 2
# Nomenclature
# 3
# Basic structure
# 4
# Legislature
# 5
# Executive
# Toggle Executive subsection
# 5.1
# President
# 5.2
# Vice president
# 5.3
# Prime minister
# 5.4
# Cabinet, ministries and agencies
# 5.4.1
# Secretaries
# 5.5
# Civil services
# 5.5.1
# Cabinet secretary
# 6
# Judiciary
# Toggle Judiciary subsection
# 6.1
# Supreme Court
# 7
# Elections and voting
# 8
# State and local governments
# 9
# Finance
# Toggle Finance subsection
# 9.1
# Taxation
# 9.2
# Union budget
# 10
# Issues
# Toggle Issues subsection
# 10.1
# Corruption
# 11
# See also
# 12
# References
# 13
# Further reading
# 14
# External links
# Toggle the table of contents
# Government of India
# 49 languages
# العربية
# অসমীয়া
# Asturianu
# Azərbaycanca
# Български
# भोजपुरी
# বাংলা
# Català
# کوردی
# Deutsch
# डोटेली
# ދިވެހިބަސް
# Ελληνικά
# Esperanto
# Español
# فارسی
# Français
# ગુજરાતી
# עברית
# हिन्दी
# Fiji Hindi
# Bahasa Indonesia
# 日本語
# ಕನ್ನಡ
# 한국어
# کٲشُر
# मैथिली
# മലയാളം
# मराठी
# Bahasa Melayu
# नेपाली
# ଓଡ଼ିଆ
# ਪੰਜਾਬੀ
# Polski
# پنجابی
# Português
# Русский
# संस्कृतम्
# ᱥᱟᱱᱛᱟᱲᱤ
# සිංහල
# Simple English
# Svenska
# தமிழ்
# తెలుగు
# ไทย
# Türkçe
# Українська
# اردو
# 中文
# Edit links
# Article
# Talk
# English
# Read
# View source
# View history
# Tools
# Tools
# move to sidebar
# hide
# Actions
# Read
# View source
# View history
# General
# What links here
# Related changes
# Upload file
# Permanent link
# Page information
# Cite this page
# Get shortened URL
# Switch to legacy parser
# Print/export
# Download as PDF
# Printable version
# In other projects
# Wikimedia Commons
# Wikiquote
# Wikiversity
# Wikidata item
# Appearance
# move to sidebar
# hide
# From Wikipedia, the free encyclopedia
# Government of India
# Bhārata S
# ## Relevant Links:
#
#
# ### Link: about page
# Wikipedia:About - Wikipedia
#
# Jump to content
# Main menu
# Main menu
# move to sidebar
# hide
# Navigation
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Contribute
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Special pages
# Search
# Search
# Appearance
# Donate
# Create account
# Log in
# Personal tools
# Donate
# Create account
# Log in
# Wikipedia
# :
# About
# 140 languages
# Аԥсшәа
# Afrikaans
# Alemannisch
# Алтай тил
# Aragonés
# अंगिका
# العربية
# الدارجة
# مصرى
# অসমীয়া
# Asturianu
# Azərbaycanca
# تۆرکجه
# Башҡортса
# Boarisch
# Bikol Central
# Беларуская (тарашкевіца)
# Беларуская
# Български
# भोजपुरी
# Banjar
# ပအိုဝ်ႏဘာႏသာႏ
# বাংলা
# བོད་ཡིག
# Català
# Нохчийн
# Cebuano
# کوردی
# Словѣньскъ / ⰔⰎⰑⰂⰡⰐⰠⰔⰍⰟ
# Чӑвашла
# Cymraeg
# Dansk
# Deutsch
# Zazaki
# ދިވެހިބަސް
# Ελληνικά
# Español
# Euskara
# فارسی
# Suomi
# Føroyskt
# Français
# Nordfriisk
# Frysk
# Gaeilge
# 贛語
# Galego
# Avañe'ẽ
# Bahasa Hulontalo
# 𐌲𐌿𐍄𐌹𐍃𐌺
# ગુજરાતી
# עברית
# हिन्दी
# Magyar
# Հայերեն
# Interlingua
# Bahasa Indonesia
# ꆇꉙ
# Ilokano
# ГӀалгӀай
# Íslenska
# Medžuslovjansky
# Italiano
# 日本語
# Jawa
# Qaraqalpaqsha
# Tyap
# Қазақша
# ភាសាខ្មែរ
# ಕನ್ನಡ
# 한국어
# کٲشُر
# Kurdî
# Кыргызча
# Lëtzebuergesch
# Lietuvių
# Latviešu
# Māori
# Македонски
# Монгол
# Bahasa Melayu
# Malti
# မြန်မာဘာသာ
# مازِرونی
# नेपाली
# Nederlands
# Norsk nynorsk
# Norsk bokmål
# Diné bizaad
# Chi-Chewa
# ଓଡ଼ିଆ
# Ирон
# ਪੰਜਾਬੀ
# Kapampangan
# Polski
# Português
# Runa Simi
# Română
# Русский
# Саха тыла
# Scots
# سنڌي
# Davvisámegiella
# Sängö
# Srpskohrvatski / српскохрватски
# တႆး
# සිංහල
# Simple English
# Slovenčina
# Slovenščina
# Soomaaliga
# Shqip
# Српски / srpski
# Sunda
# Svenska
# Kiswahili
# ꠍꠤꠟꠐꠤ
# தமிழ்
# తెలుగు
# Тоҷикӣ
# ไทย
# Türkmençe
# Tagalog
# Türkçe
# Татарча / tatarça
# Удмурт
# ئۇيغۇرچە / Uyghurche
# Українська
# اردو
# Oʻzbekcha / ўзбекча
# Tiếng Việt
# Walon
# Winaray
# Wolof
# 吴语
# მარგალური
# ייִדיש
# Yorùbá
# 粵語
# 中文
# Edit links
# Project page
# Talk
# English
# Read
# View source
# View history
# Tools
# Tools
# move to sidebar
# hide
# Actions
# Read
# View source
# View history
# General
# What links here
# Related changes
# Upload file
# Permanent link
# Page information
# Get shortened URL
# Print/export
# Download as PDF
# Printable version
# In other projects
# Abstract Wikipedia
# Wikimedia Com

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# brochure_system_prompt = """
# You are an assistant that analyzes the contents of several relevant pages from a company website
# and creates a short, humorous, entertaining, witty brochure about the company for prospective customers, investors and recruits.
# Respond in markdown without code blocks.
# Include details of company culture, customers and careers/jobs if you have the information.
# """

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a company called: {company_name}
Here are the contents of its landing page and other relevant pages;
use this information to build a short brochure of the company in markdown without code blocks.\n\n
"""
    user_prompt += fetch_page_and_all_relevant_links(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
display(Markdown(get_brochure_user_prompt("HuggingFace", "https://huggingface.co")))

# %%
def create_brochure(company_name, url):
    response = client.models.generate_content(
        model=MODEL,
        contents =get_brochure_user_prompt(company_name, url),
        config={
            "system_instruction": brochure_system_prompt
            }
        
    )
    result = response.text
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# # Hugging Face
# ## The AI Community Building the Future
#
# Welcome to Hugging Face, the ultimate collaboration platform and home of machine learning where developers, researchers, and organizations come together to build the future of artificial intelligence.
#
# ### What We Do
# Hugging Face provides the central hub for the global machine learning ecosystem. We empower users to create, discover, and collaborate on cutting-edge AI applications, models, datasets, and infrastructure.
#
# Our robust platform offers access to:
# * **Over 2 Million Models:** Explore a massive repository of state-of-the-art machine learning models for NLP, computer vision, audio, reinforcement learning, and more.
# * **Over 500k Datasets:** Access rich data sources to train, fine-tune, and evaluate your AI systems.
# * **Interactive Spaces:** Discover and run over 1 million live AI applications and demos directly in your browser.
# * **Enterprise Solutions:** Scale your AI initiatives securely with Hugging Face PRO, Enterprise Support, dedicated Inference Endpoints, and Storage Buckets.
#
# ### Company Culture & Community
# At Hugging Face, community is at the heart of everything we do. We believe in open-source collaboration, transparency, and pushing the boundaries of AI research together. Whether you are discussing the latest daily research papers on our forum and Discord, building agentic workflows, or sharing insights via community articles and blogs, our platform thrives on the collective brilliance of over 100,000 active members and contributors worldwide.
#
# ### Customers & Partners
# Hugging Face serves a diverse ecosystem of customers and partners ranging from independent developers and academic researchers to major technology leaders and global enterprises. Organizations leverage our ecosystem—including inference providers, hardware integrations, and custom solutions—to streamline their machine learning pipelines and accelerate AI deployment at scale.
#
# ### Careers & Joining Us
# Are you passionate about shaping the global open-source AI ecosystem? Join a fast-growing, dynamic team of builders, researchers, and innovators dedicated to democratizing good machine learning. At Hugging Face, you will work on the bleeding edge of technology alongside top-tier talent.
#
# Visit our platform to explore our repositories, join the community, and start building the future with us today!
